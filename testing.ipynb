# %%
print(5+5)
thing=5
thing -= 1
print(thing)
# Out:
# 10
# 4

# %%
card = None
if not (card):
    print("yes")
# Out:
# yes

# %%
thing = {"b":3, "c":5}

print(list(thing))
# Out:
# ['b', 'c']

# %%
t = {"Copper":1, "Silver":2, "Gold":3}
b = list(t)
b.remove("Copper")

print(t.get("bopper"))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-9-ef8e6a5a478e> in <module>
#       3 b.remove("Copper")
#       4
# ----> 5 print(t.get("bopper")+3)
#
# TypeError: unsupported operand type(s) for +: 'NoneType' and 'int'

# %%
bop = [0,0]
bop[1]=1
print(bop)
# Out:
# [0, 1]

# %%
import random
random.choice(list({"me":1, "you":2}))
# Out:
# 'me'

# %%
random.randint(4)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-21-0f8418459ae8> in <module>
# ----> 1 random.randint(4)
#
# TypeError: randint() missing 1 required positional argument: 'b'
