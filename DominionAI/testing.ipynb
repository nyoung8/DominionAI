# %%
print(5+5)
thing=5
thing -= 1
print(thing)
# Out:
# 10
# 4

# %%
card = None
if not (card):
    print("yes")
# Out:
# yes

# %%
thing = {"b":3, "c":5}

print(list(thing))
# Out:
# ['b', 'c']

# %%
t = {"Copper":1, "Silver":2, "Gold":3}
b = list(t)
b.remove("Copper")

print(t.get("bopper"))
# Out:
# None

# %%
bop = [0,0]
bop[1]=1
print(bop)
# Out:
# [0, 1]

# %%
import random
random.choice(list({"me":1, "you":2}))
# Out:
# 'me'

# %%
random.randint(4)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-46-0f8418459ae8> in <module>
# ----> 1 random.randint(4)
#
# TypeError: randint() missing 1 required positional argument: 'b'

# %%
wins = [0]*10
for i in wins:
    i=1
print(str(wins))

# %%
import numpy as np
s=3
print(str(np.identity(5)[s:s + 1]))

# %%
import sys
b = 0
print(b)
for i in range(5):
    b=i
    sys.exit()
print(b)
# Out:
# 0
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit
# /opt/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3334: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)

# %%
a=b=min(5,3)
a
# Out:
# 3

# %%
b="bleh"
print(b=="bleh")
# Out:
# True

# %%
print([8,5][0])
# Out:
# 8
